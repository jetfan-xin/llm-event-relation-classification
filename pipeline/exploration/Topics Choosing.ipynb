# %%
from nltk.corpus import wordnet as wn

# %%
wn.langs()
# Out:
# ['eng']

# %%
wn.synonyms('hot')
# Out:
# [[],
#  ['raging'],
#  [],
#  [],
#  [],
#  [],
#  ['blistering', 'red-hot'],
#  [],
#  ['spicy'],
#  [],
#  [],
#  [],
#  ['red-hot'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['live'],
#  []]

# %%
hot = wn.synset('hot.a.01').lemmas()[0]
hot.antonyms()
# Out:
# [Lemma('cold.a.01.cold')]

# %%
hot.lemmas()
# Out:
# [Lemma('hot.a.01.hot')]
